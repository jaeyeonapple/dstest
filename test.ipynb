# %%
print("Hello World")
# Out:
# Hello World

# %%
1+2
# Out:
# 3

# %%
a = 10 * 20
print(a)
# Out:
# 200

# %%
happy = True
excited = False

# %%
not happy
# Out:
# False

# %%
happy  and excited
# Out:
# False

# %%
if happy:
    print("I'am happy")
# Out:
# I'am happy

# %%
happy = False

# %%
mood = "soso"

# %%
if mood == "high":
    print("I'm happy")
elif mood == "low":
    print("I am not happy")
else:
    print("?")
# Out:
# ?

# %%
a = [10, 30, 40, 50]
print(a)
# Out:
# [10, 30, 40, 50]

# %%
print(a[0])
# Out:
# 10

# %%
len(a)
# Out:
# 4

# %%
a = {}

# %%
a["name"] = "hyojung"
a["gender"] = "male"

# %%
print(a)
# Out:
# {'name': 'hyojung', 'gender': 'male'}

# %%
def hello():
    print("hello")

# %%
import numpy as np

# %%
x = np.array([1.0, 2.0, 3.0])

# %%
print(x)
# Out:
# [1. 2. 3.]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y = np.array([2.0, 4.0, 6.0])

# %%
x + y
# Out:
# array([3., 6., 9.])

# %%
x*y
# Out:
# array([ 2.,  8., 18.])

# %%
x/y
# Out:
# array([0.5, 0.5, 0.5])

# %%
A = np.array([[1, 2], [3, 4]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A.shape
# Out:
# (2, 2)

# %%
X = A.flatten()

# %%
X
# Out:
# array([1, 2, 3, 4])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 6, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
import imageio

# %%
img = imageio.imread('6-1.jpg')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_35348\2653312023.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('6-1.jpg')

# %%
plt.imshow(img)

# %%
# %matplotlib widget
